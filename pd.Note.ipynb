# %%
import pandas as pd
dfLFPR =  pd.read_csv("~/../smehkari/EconCourses/data/LFPRData.csv")

# %%
dfLFPR
# Out:
#            date  LFPR  LFPR-Men  LFPR-Women  LFPR-16-19  LFPR-20-24  \
# 0    1948-01-01  58.6      86.7        32.0        53.2        64.4
# 1    1948-02-01  58.9      87.0        32.4        53.7        64.9
# 2    1948-03-01  58.5      86.3        32.1        54.1        63.3
# 3    1948-04-01  59.0      86.6        33.0        54.2        63.7
# 4    1948-05-01  58.3      86.1        32.0        50.9        63.7
# ..          ...   ...       ...         ...         ...         ...
# 883  2021-08-01  61.7      67.7        56.2        36.3        70.2
# 884  2021-09-01  61.7      67.7        56.0        36.3        70.6
# 885  2021-10-01  61.7      67.7        56.1        36.3        71.2
# 886  2021-11-01  61.9      67.8        56.3        36.4        71.9
# 887  2021-12-01  61.9      67.7        56.5        36.1        72.0
#
#      LFPR-25-54  LFPR-55+
# 0          64.2      43.0
# 1          64.6      43.3
# 2          64.3      43.0
# 3          64.8      43.4
# ...

# %%
dfLFPR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 888 entries, 0 to 887
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        888 non-null    object
#  1   LFPR        888 non-null    float64
#  2   LFPR-Men    888 non-null    float64
#  3   LFPR-Women  888 non-null    float64
#  4   LFPR-16-19  888 non-null    float64
#  5   LFPR-20-24  888 non-null    float64
#  6   LFPR-25-54  888 non-null    float64
#  7   LFPR-55+    888 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 55.6+ KB

# %%
dfLFPR2 = dfLFPR.copy()
dfLFPR2
# Out:
#            date  LFPR  LFPR-Men  LFPR-Women  LFPR-16-19  LFPR-20-24  \
# 0    1948-01-01  58.6      86.7        32.0        53.2        64.4
# 1    1948-02-01  58.9      87.0        32.4        53.7        64.9
# 2    1948-03-01  58.5      86.3        32.1        54.1        63.3
# 3    1948-04-01  59.0      86.6        33.0        54.2        63.7
# 4    1948-05-01  58.3      86.1        32.0        50.9        63.7
# ..          ...   ...       ...         ...         ...         ...
# 883  2021-08-01  61.7      67.7        56.2        36.3        70.2
# 884  2021-09-01  61.7      67.7        56.0        36.3        70.6
# 885  2021-10-01  61.7      67.7        56.1        36.3        71.2
# 886  2021-11-01  61.9      67.8        56.3        36.4        71.9
# 887  2021-12-01  61.9      67.7        56.5        36.1        72.0
#
#      LFPR-25-54  LFPR-55+
# 0          64.2      43.0
# 1          64.6      43.3
# 2          64.3      43.0
# 3          64.8      43.4
# ...

# %%
dfLFPR2.dropna()
# Out:
#            date  LFPR  LFPR-Men  LFPR-Women  LFPR-16-19  LFPR-20-24  \
# 0    1948-01-01  58.6      86.7        32.0        53.2        64.4
# 1    1948-02-01  58.9      87.0        32.4        53.7        64.9
# 2    1948-03-01  58.5      86.3        32.1        54.1        63.3
# 3    1948-04-01  59.0      86.6        33.0        54.2        63.7
# 4    1948-05-01  58.3      86.1        32.0        50.9        63.7
# ..          ...   ...       ...         ...         ...         ...
# 883  2021-08-01  61.7      67.7        56.2        36.3        70.2
# 884  2021-09-01  61.7      67.7        56.0        36.3        70.6
# 885  2021-10-01  61.7      67.7        56.1        36.3        71.2
# 886  2021-11-01  61.9      67.8        56.3        36.4        71.9
# 887  2021-12-01  61.9      67.7        56.5        36.1        72.0
#
#      LFPR-25-54  LFPR-55+
# 0          64.2      43.0
# 1          64.6      43.3
# 2          64.3      43.0
# 3          64.8      43.4
# ...

# %%
import pandas as pd

# %%
dfECON = pd.read_csv("~/../smehkari/EconCourses/data/econdata1.csv")
dfECON
#NaN no a number
# Out:
#       county_fips        county_name  state_fips state_name state_code  \
# 0            1001     Autauga County           1    Alabama         AL
# 1            1003     Baldwin County           1    Alabama         AL
# 2            1005     Barbour County           1    Alabama         AL
# 3            1007        Bibb County           1    Alabama         AL
# 4            1009      Blount County           1    Alabama         AL
# ...           ...                ...         ...        ...        ...
# 3141        56037  Sweetwater County          56    Wyoming         WY
# 3142        56039       Teton County          56    Wyoming         WY
# 3143        56041       Uinta County          56    Wyoming         WY
# 3144        56043    Washakie County          56    Wyoming         WY
# 3145        56045      Weston County          56    Wyoming         WY
#
#       division_number                division_name  region_number  \
# ...

# %%
dfECON.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3146 entries, 0 to 3145
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   county_fips                 3146 non-null   int64
#  1   county_name                 3146 non-null   object
#  2   state_fips                  3146 non-null   int64
#  3   state_name                  3146 non-null   object
#  4   state_code                  3146 non-null   object
#  5   division_number             3146 non-null   int64
#  6   division_name               3146 non-null   object
#  7   region_number               3146 non-null   int64
#  8   region_name                 3146 non-null   object
#  9   unrate                      3141 non-null   float64
#  10  medianhhincome              3141 non-null   float64
#  11  less_than_high_school_perc  3142 non-null   float64
#  12  high_school_only_perc       3142 non-null   float64
# ...

# %%
dfECON2 = dfECON.copy()
dfECON2
# Out:
#       county_fips        county_name  state_fips state_name state_code  \
# 0            1001     Autauga County           1    Alabama         AL
# 1            1003     Baldwin County           1    Alabama         AL
# 2            1005     Barbour County           1    Alabama         AL
# 3            1007        Bibb County           1    Alabama         AL
# 4            1009      Blount County           1    Alabama         AL
# ...           ...                ...         ...        ...        ...
# 3141        56037  Sweetwater County          56    Wyoming         WY
# 3142        56039       Teton County          56    Wyoming         WY
# 3143        56041       Uinta County          56    Wyoming         WY
# 3144        56043    Washakie County          56    Wyoming         WY
# 3145        56045      Weston County          56    Wyoming         WY
#
#       division_number                division_name  region_number  \
# ...

# %%
dfECON2.dropna()
# Out:
#       county_fips        county_name  state_fips state_name state_code  \
# 4            1009      Blount County           1    Alabama         AL
# 15           1031      Coffee County           1    Alabama         AL
# 22           1045        Dale County           1    Alabama         AL
# 23           1047      Dallas County           1    Alabama         AL
# 37           1075       Lamar County           1    Alabama         AL
# ...           ...                ...         ...        ...        ...
# 3097        55091       Pepin County          55  Wisconsin         WI
# 3117        55131  Washington County          55  Wisconsin         WI
# 3120        55137    Waushara County          55  Wisconsin         WI
# 3122        55141        Wood County          55  Wisconsin         WI
# 3135        56025     Natrona County          56    Wyoming         WY
#
#       division_number                division_name  region_number  \
# ...

# %%
dfWDID = pd.read_csv('~/../smehkari/EconCourses/data/WDIData2.csv',na_values = '..')
dfWDID
# Out:
#       Time Time Code                                Country Name Country Code  \
# 0     2000    YR2000                                 Afghanistan          AFG
# 1     2000    YR2000                                     Albania          ALB
# 2     2000    YR2000                                     Algeria          DZA
# 3     2000    YR2000                              American Samoa          ASM
# 4     2000    YR2000                                     Andorra          AND
# ...    ...       ...                                         ...          ...
# 3719  2020    YR2020                          Sub-Saharan Africa          SSF
# 3720  2020    YR2020  Sub-Saharan Africa (excluding high income)          SSA
# 3721  2020    YR2020   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 3722  2020    YR2020                         Upper middle income          UMC
# 3723  2020    YR2020                                       World          WLD
#
# ...

# %%
dfWDID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3724 entries, 0 to 3723
# Data columns (total 14 columns):
#  #   Column                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                 --------------  -----
#  0   Time                                                                                                   3724 non-null   int64
#  1   Time Code                                                                                              3724 non-null   object
#  2   Country Name                                                                                           3724 non-null   object
#  3   Country Code                                                                                           3724 non-null   object
# ...

# %%
dfWDID2 = dfWDID.copy()
dfWDID2
# Out:
#       Time Time Code                                Country Name Country Code  \
# 0     2000    YR2000                                 Afghanistan          AFG
# 1     2000    YR2000                                     Albania          ALB
# 2     2000    YR2000                                     Algeria          DZA
# 3     2000    YR2000                              American Samoa          ASM
# 4     2000    YR2000                                     Andorra          AND
# ...    ...       ...                                         ...          ...
# 3719  2020    YR2020                          Sub-Saharan Africa          SSF
# 3720  2020    YR2020  Sub-Saharan Africa (excluding high income)          SSA
# 3721  2020    YR2020   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 3722  2020    YR2020                         Upper middle income          UMC
# 3723  2020    YR2020                                       World          WLD
#
# ...

# %%
dfWDID2.dropna()
# Out:
#       Time Time Code                                Country Name Country Code  \
# 0     2000    YR2000                                 Afghanistan          AFG
# 1     2000    YR2000                                     Albania          ALB
# 2     2000    YR2000                                     Algeria          DZA
# 3     2000    YR2000                              American Samoa          ASM
# 4     2000    YR2000                                     Andorra          AND
# ...    ...       ...                                         ...          ...
# 3719  2020    YR2020                          Sub-Saharan Africa          SSF
# 3720  2020    YR2020  Sub-Saharan Africa (excluding high income)          SSA
# 3721  2020    YR2020   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 3722  2020    YR2020                         Upper middle income          UMC
# 3723  2020    YR2020                                       World          WLD
#
# ...

# %%
dfLFPR = pd.read_csv('~/../smehkari/EconCourses/data/LFPRData.csv')
dfLFPR
# Out:
#            date  LFPR  LFPR-Men  LFPR-Women  LFPR-16-19  LFPR-20-24  \
# 0    1948-01-01  58.6      86.7        32.0        53.2        64.4
# 1    1948-02-01  58.9      87.0        32.4        53.7        64.9
# 2    1948-03-01  58.5      86.3        32.1        54.1        63.3
# 3    1948-04-01  59.0      86.6        33.0        54.2        63.7
# 4    1948-05-01  58.3      86.1        32.0        50.9        63.7
# ..          ...   ...       ...         ...         ...         ...
# 883  2021-08-01  61.7      67.7        56.2        36.3        70.2
# 884  2021-09-01  61.7      67.7        56.0        36.3        70.6
# 885  2021-10-01  61.7      67.7        56.1        36.3        71.2
# 886  2021-11-01  61.9      67.8        56.3        36.4        71.9
# 887  2021-12-01  61.9      67.7        56.5        36.1        72.0
#
#      LFPR-25-54  LFPR-55+
# 0          64.2      43.0
# 1          64.6      43.3
# 2          64.3      43.0
# 3          64.8      43.4
# ...

# %%
dfLFPR.describe()
# Out:
#              LFPR    LFPR-Men  LFPR-Women  LFPR-16-19  LFPR-20-24  LFPR-25-54  \
# count  888.000000  888.000000  888.000000  888.000000  888.000000  888.000000
# mean    62.851014   77.134234   49.886599   47.913851   71.843243   77.070608
# std      2.959551    5.210189    9.379676    7.065575    5.320895    6.486057
# min     58.100000   66.100000   32.000000   30.000000   59.300000   64.200000
# 25%     59.700000   73.600000   40.175000   44.100000   66.700000   70.200000
# 50%     62.950000   76.400000   54.000000   50.200000   72.300000   80.750000
# 75%     66.000000   80.500000   58.000000   53.200000   77.000000   82.800000
# max     67.300000   87.400000   60.300000   59.300000   79.600000   84.600000
#
#          LFPR-55+
# count  888.000000
# mean    36.694144
# std      4.452752
# min     29.200000
# 25%     32.200000
# 50%     38.500000
# 75%     40.200000
# max     43.600000

# %%
dfLFPR['date'] = dfLFPR['date'].astype("datetime64")

# %%
dfLFPR.plot(x='date', y='LFPR')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dfLFPR.plot(x = 'date', y = ['LFPR-Men','LFPR-Women'])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
dfECON = pd.read_csv('~/../smehkari/EconCourses/data/econdata1.csv')
dfECON
# Out:
#       county_fips        county_name  state_fips state_name state_code  \
# 0            1001     Autauga County           1    Alabama         AL
# 1            1003     Baldwin County           1    Alabama         AL
# 2            1005     Barbour County           1    Alabama         AL
# 3            1007        Bibb County           1    Alabama         AL
# 4            1009      Blount County           1    Alabama         AL
# ...           ...                ...         ...        ...        ...
# 3141        56037  Sweetwater County          56    Wyoming         WY
# 3142        56039       Teton County          56    Wyoming         WY
# 3143        56041       Uinta County          56    Wyoming         WY
# 3144        56043    Washakie County          56    Wyoming         WY
# 3145        56045      Weston County          56    Wyoming         WY
#
#       division_number                division_name  region_number  \
# ...

# %%
dfECON.corr()
# Out:
#                             county_fips  state_fips  division_number  \
# county_fips                    1.000000    0.999975        -0.062519
# state_fips                     0.999975    1.000000        -0.063109
# division_number               -0.062519   -0.063109         1.000000
# region_number                 -0.086478   -0.086992         0.936489
# unrate                        -0.103044   -0.103077         0.176629
# medianhhincome                 0.040053    0.040512        -0.113088
# less_than_high_school_perc    -0.003828   -0.005226         0.258624
# high_school_only_perc          0.002767    0.003052        -0.189709
# some_college_only_perc        -0.055021   -0.054459         0.107175
# bachelors_and_higher_perc      0.030818    0.031229        -0.088411
# crimes                        -0.091914   -0.091757         0.067806
# disconnected_youth            -0.054918   -0.055319         0.185712
# poverty                       -0.053575   -0.053392         0.025525
# ...

# %%
dfECON.nlargest(5,'medianhhincome')
# Out:
#       county_fips         county_name  state_fips  state_name state_code  \
# 2875        51107      Loudoun County          51    Virginia         VA
# 2929        51610   Falls Church city          51    Virginia         VA
# 231          6085  Santa Clara County           6  California         CA
# 1813        35028   Los Alamos County          35  New Mexico         NM
# 209          6041        Marin County           6  California         CA
#
#       division_number            division_name  region_number   region_name  \
# 2875                5  South Atlantic Division              3  South Region
# 2929                5  South Atlantic Division              3  South Region
# 231                 9         Pacific Division              4   West Region
# 1813                8        Mountain Division              4   West Region
# 209                 9         Pacific Division              4   West Region
#
# ...

# %%
dfECON['region_name'].value_counts()
# Out:
# South Region        1423
# Midwest Region      1055
# West Region          451
# Northeast Region     217
# Name: region_name, dtype: int64

# %%
dfECON.plot.scatter(x='medianhhincome', y = 'bachelors_and_higher_perc')
# Out:
# <AxesSubplot:xlabel='medianhhincome', ylabel='bachelors_and_higher_perc'>

# %%
dfECON.count()
# Out:
# county_fips                   3146
# county_name                   3146
# state_fips                    3146
# state_name                    3146
# state_code                    3146
# division_number               3146
# division_name                 3146
# region_number                 3146
# region_name                   3146
# unrate                        3141
# medianhhincome                3141
# less_than_high_school_perc    3142
# high_school_only_perc         3142
# some_college_only_perc        3142
# bachelors_and_higher_perc     3142
# crimes                        2320
# disconnected_youth            3137
# poverty                       3139
# snap_benefits                 3139
# subprime_perc                  410
# home_ownership_rate           3140
# dtype: int64

# %%
dfECON.columns.to_list()
# Out:
# ['county_fips',
#  'county_name',
#  'state_fips',
#  'state_name',
#  'state_code',
#  'division_number',
#  'division_name',
#  'region_number',
#  'region_name',
#  'unrate',
#  'medianhhincome',
#  'less_than_high_school_perc',
#  'high_school_only_perc',
#  'some_college_only_perc',
#  'bachelors_and_higher_perc',
#  'crimes',
#  'disconnected_youth',
#  'poverty',
#  'snap_benefits',
#  'subprime_perc',
#  'home_ownership_rate']

# %%
# Out:
#   File "/tmp/ipykernel_2192357/2015659830.py", line 8
#     def main(): x=A(1) y=A(1)
#                        ^
# SyntaxError: invalid syntax
